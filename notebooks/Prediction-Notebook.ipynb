# %% [markdown]
# # Machine Learning Operation (MlOps)

# %% [markdown]
# ### This is from the MlOps ZoomCamp

# %%
"""List the various libraries needed for the work"""
import pandas as pd

# %% [markdown]
# ### Loading the data accordingly

# %%
df = pd.read_parquet("./data/green_tripdata_2021-01.parquet")

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# ...

# %%
# The number of data available and shape of data
print("The shape of data is: ", df.shape)
# Out:
# The shape of data is:  (76518, 20)

# %%
### Data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               76518 non-null  int64
#  1   lpep_pickup_datetime   76518 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  76518 non-null  datetime64[ns]
#  3   store_and_fwd_flag     40471 non-null  object
#  4   RatecodeID             40471 non-null  float64
#  5   PULocationID           76518 non-null  int64
#  6   DOLocationID           76518 non-null  int64
#  7   passenger_count        40471 non-null  float64
#  8   trip_distance          76518 non-null  float64
#  9   fare_amount            76518 non-null  float64
#  10  extra                  76518 non-null  float64
#  11  mta_tax                76518 non-null  float64
#  12  tip_amount             76518 non-null  float64
#  13  tolls_amount           76518 non-null  float64
# ...

# %%
df_trip_type_2 = df[df.trip_type ==2]

# %%
df_trip_type_2
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 6             2  2021-01-01 00:19:14   2021-01-01 00:19:21                  N
# 15            2  2021-01-01 00:29:05   2021-01-01 00:29:07                  N
# 30            2  2021-01-01 00:35:29   2021-01-01 00:55:15                  N
# 43            2  2021-01-01 23:12:41   2021-01-02 01:13:53                  N
# 45            2  2021-01-01 01:49:29   2021-01-01 01:49:33                  N
# ...         ...                  ...                   ...                ...
# 40363         2  2021-01-31 19:26:20   2021-01-31 19:35:47                  N
# 40364         2  2021-01-31 19:44:54   2021-01-31 20:19:56                  N
# 40377         2  2021-01-31 20:09:41   2021-01-31 20:10:21                  N
# 40394         2  2021-01-31 20:38:42   2021-01-31 20:38:45                  N
# 40430         2  2021-01-31 21:48:08   2021-01-31 22:11:17                  N
#
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df['time_Travel'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime

# %%
df['time_Travel']
# Out:
# 0       0 days 00:03:56
# 1       0 days 00:08:45
# 2       0 days 00:05:58
# 3       0 days 00:07:05
# 4       0 days 00:00:04
#               ...
# 76513   0 days 00:38:00
# 76514   0 days 00:38:00
# 76515   0 days 00:11:00
# 76516   0 days 00:27:00
# 76517   0 days 00:10:00
# Name: time_Travel, Length: 76518, dtype: timedelta64[ns]

# %%
time_travel = df.time_Travel.iloc[0]
time_travel.total_seconds()
# Out:
# 236.0

# %%
df.time_Travel.apply(lambda time_travel: time_travel.total_seconds()/60 )
# Out:
# 0         3.933333
# 1         8.750000
# 2         5.966667
# 3         7.083333
# 4         0.066667
#            ...
# 76513    38.000000
# 76514    38.000000
# 76515    11.000000
# 76516    27.000000
# 76517    10.000000
# Name: time_Travel, Length: 76518, dtype: float64

# %%
df.time_Travel.describe(percentiles=[0.95, 0.97, 0.99])
# Out:
# count                        76518
# mean     0 days 00:19:55.673763036
# std      0 days 00:59:20.315647898
# min                0 days 00:00:00
# 50%                0 days 00:13:53
# 95%                0 days 00:44:00
# 97%      0 days 00:50:11.489999999
# 99%         0 days 01:07:09.490000
# max                0 days 23:59:36
# Name: time_Travel, dtype: object

# %%
(df.time_Travel >= 1) & (df.time_Travel <= 60)
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py:1008, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1007 try:
# -> 1008     other = self._validate_comparison_value(other)
#    1009 except InvalidComparison:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py:542, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     541 elif not is_list_like(other):
# --> 542     raise InvalidComparison(other)
#     544 elif len(other) != len(self):
#
# InvalidComparison: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 (df.time_Travel >= 1) & (df.time_Travel <= 60)
#
# ...

# %%
df_1 = df[(df.time_Travel >= 1) & (df.time_Travel <= 60)]
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py:1008, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1007 try:
# -> 1008     other = self._validate_comparison_value(other)
#    1009 except InvalidComparison:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py:542, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     541 elif not is_list_like(other):
# --> 542     raise InvalidComparison(other)
#     544 elif len(other) != len(self):
#
# InvalidComparison: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df_1 = df[(df.time_Travel >= 1) & (df.time_Travel <= 60)]
#
# ...
